# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1)

# %%
df=pd.read_csv("50ulke.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head()
# Out:
#         Countries  National Income  Growth  Per person      Continent
# 0   United States         20412.87    2.27     62152.0  North America
# 1           China         14092.51    6.86     10088.0           Asia
# 2           Japan          5167.05    1.71     40849.0           Asia
# 3         Germany          4211.64    2.51     50842.0         Europe
# 4  United Kingdom          2936.29    1.79     44177.0         Europe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# Countries          50 non-null object
# National Income    50 non-null float64
# Growth             50 non-null float64
# Per person         50 non-null float64
# Continent          50 non-null object
# dtypes: float64(3), object(2)
# memory usage: 2.0+ KB

# %%
df.describe()
# Out:
#        National Income     Growth    Per person
# count        50.000000  50.000000     50.000000
# mean       1646.348200   3.320400  27696.000000
# std        3448.554429   2.053468  25094.131496
# min         231.570000  -0.740000   1615.000000
# 25%         353.440000   1.795000   6402.000000
# 50%         522.985000   2.880000  14565.500000
# 75%        1504.895000   4.287500  48738.250000
# max       20412.870000   7.810000  86835.000000

# %%
df.groupby("Continent").describe()
# Out:
#               National Income                                               \
#                         count         mean           std      min      25%
# Continent
# Africa                    3.0   344.250000     81.033633   253.25   312.07
# Asia                     19.0  1636.765263   3246.859477   240.78   357.22
# Europe                   19.0  1139.841579   1147.361596   245.59   377.45
# North America             3.0  7808.070000  10920.004237  1212.83  1505.67
# Oceania                   1.0  1500.260000           NaN  1500.26  1500.26
# South America             5.0   720.932000    807.432147   231.57   280.27
#
#                                            Growth            ...               \
#                    50%       75%       max  count      mean  ...    75%   max
# Continent                                                    ...
# Africa          370.89    389.75    408.61    3.0  2.123333  ...  2.775  4.23
# ...

# %%
#df[df["Continent"]=="Africa"].groupby("Countries").describe()
df[df["Continent"]=="Africa"].groupby("Countries").mean()
# Out:
#               National Income  Growth  Per person
# Countries
# Egypt                  253.25    4.23      2611.0
# Nigeria                408.61    0.82      2108.0
# South Africa           370.89    1.32      6459.0

# %%
df[df["Continent"]=="Asia"].groupby("Countries").describe()
#df[df["Continent"]=="Asia"].groupby("Countries").mean()
# Out:
#                          National Income                                    \
#                                    count      mean std       min       25%
# Countries
# Bangladesh                           1.0    285.82 NaN    285.82    285.82
# China                                1.0  14092.51 NaN  14092.51  14092.51
# Hong Kong SAR                        1.0    364.78 NaN    364.78    364.78
# India                                1.0   2848.23 NaN   2848.23   2848.23
# Indonesia                            1.0   1074.97 NaN   1074.97   1074.97
# Islamic Republic of Iran             1.0    418.88 NaN    418.88    418.88
# Israel                               1.0    373.75 NaN    373.75    373.75
# Japan                                1.0   5167.05 NaN   5167.05   5167.05
# Korea                                1.0   1693.25 NaN   1693.25   1693.25
# Malaysia                             1.0    364.92 NaN    364.92    364.92
# ...

# %%
df[df["Continent"]=="Europe"].groupby("Countries").mean()
#df[df["Continent"]=="Europe"].groupby("Countries").describe()
# Out:
#                 National Income  Growth  Per person
# Countries
# Austria                  477.67    2.90     53764.0
# Belgium                  562.23    1.71     49272.0
# Czech Republic           251.58    4.29      2375.0
# Denmark                  369.76    2.11      6383.0
# Finland                  289.56    2.99     52422.0
# France                  2925.10    1.85     44934.0
# Germany                 4211.64    2.51     50842.0
# Ireland                  385.14    7.81     80641.0
# Italy                   2181.97    1.47     35914.0
# Netherlands              945.33    3.11     55185.0
# Norway                   443.25    1.81     82711.0
# Poland                   614.19    4.55      1618.0
# Portugal                 248.89    2.67     24237.0
# Romania                  245.59    7.00     12575.0
# Russia                  1719.90    1.55     11947.0
# Spain                   1506.44    3.05     32559.0
# Sweden                   600.77    2.40     58345.0
# ...

# %%
df[df["Continent"]=="North America"].groupby("Countries").mean()
#df[df["Continent"]=="North America"].groupby("Countries").describe()
# Out:
#                National Income  Growth  Per person
# Countries
# Canada                 1798.51    3.00     48466.0
# Mexico                 1212.83    2.04      9723.0
# United States         20412.87    2.27     62152.0

# %%
df[df["Continent"]=="Oceania"].groupby("Countries").mean()
#df[df["Continent"]=="Oceania"].groupby("Countries").describe()
# Out:
#            National Income  Growth  Per person
# Countries
# Australia          1500.26    2.27     59655.0

# %%
df[df["Continent"]=="South America"].groupby("Countries").mean()
#df[df["Continent"]=="South America"].groupby("Countries").describe()
# Out:
#            National Income  Growth  Per person
# Countries
# Argentina           625.92    2.86     14044.0
# Brazil             2138.92    0.98     10224.0
# Chile               280.27    1.47     15087.0
# Colombia            327.98    1.77      6581.0
# Peru                231.57    2.51      7199.0

# %%
dfAfrica=pd.DataFrame(data=df[df["Continent"]=="Africa"])

# %%
dfAfrica.drop("Continent",inplace=True,axis=1)

# %%
dfAfrica
# Out:
#        Countries  National Income  Growth  Per person
# 30       Nigeria           408.61    0.82      2108.0
# 33  South Africa           370.89    1.32      6459.0
# 44         Egypt           253.25    4.23      2611.0

# %%
dfAsia=pd.DataFrame(data=df[df["Continent"]=="Asia"])

# %%
dfAsia.drop("Continent",inplace=True,axis=1)

# %%
dfAsia
# Out:
#                    Countries  National Income  Growth  Per person
# 1                      China         14092.51    6.86     10088.0
# 2                      Japan          5167.05    1.71     40849.0
# 6                      India          2848.23    6.74      2135.0
# 11                     Korea          1693.25    3.09     32775.0
# 15                 Indonesia          1074.97    5.07      4052.0
# 17                    Turkey           909.89    7.05     11114.0
# 18              Saudi Arabia           748.00   -0.74      2265.0
# 22  Taiwan Province of China           613.30    2.79     25977.0
# 25                  Thailand           483.74    3.90      6992.0
# 28  Islamic Republic of Iran           418.88    4.28      5086.0
# 29      United Arab Emirates           411.83    0.53     39484.0
# 32                    Israel           373.75    3.32     42115.0
# 35                  Malaysia           364.92    5.90     11237.0
# ...

# %%
dfEurope=pd.DataFrame(data=df[df["Continent"]=="Europe"])

# %%
dfEurope.drop("Continent",inplace=True,axis=1)

# %%
dfEurope
# Out:
#          Countries  National Income  Growth  Per person
# 3          Germany          4211.64    2.51     50842.0
# 4   United Kingdom          2936.29    1.79     44177.0
# 5           France          2925.10    1.85     44934.0
# 7            Italy          2181.97    1.47     35914.0
# 10          Russia          1719.90    1.55     11947.0
# 12           Spain          1506.44    3.05     32559.0
# 16     Netherlands           945.33    3.11     55185.0
# 19     Switzerland           741.69    1.07     86835.0
# 21          Poland           614.19    4.55      1618.0
# 23          Sweden           600.77    2.40     58345.0
# 24         Belgium           562.23    1.71     49272.0
# 26         Austria           477.67    2.90     53764.0
# 27          Norway           443.25    1.81     82711.0
# 31         Ireland           385.14    7.81     80641.0
# 34         Denmark           369.76    2.11      6383.0
# 41         Finland           289.56    2.99     52422.0
# ...

# %%
dfOceania=pd.DataFrame(data=df[df["Continent"]=="Oceania"])

# %%
dfOceania.drop("Continent",inplace=True,axis=1)

# %%
dfOceania
# Out:
#     Countries  National Income  Growth  Per person
# 13  Australia          1500.26    2.27     59655.0

# %%
dfnthAmerica=pd.DataFrame(data=df[df["Continent"]=="North America"])

# %%
dfnthAmerica.drop("Continent",inplace=True,axis=1)

# %%
dfnthAmerica
# Out:
#         Countries  National Income  Growth  Per person
# 0   United States         20412.87    2.27     62152.0
# 9          Canada          1798.51    3.00     48466.0
# 14         Mexico          1212.83    2.04      9723.0

# %%
dfsthAmerica=pd.DataFrame(data=df[df["Continent"]=="South America"])

# %%
dfsthAmerica
# Out:
#     Countries  National Income  Growth  Per person      Continent
# 8      Brazil          2138.92    0.98     10224.0  South America
# 20  Argentina           625.92    2.86     14044.0  South America
# 39   Colombia           327.98    1.77      6581.0  South America
# 43      Chile           280.27    1.47     15087.0  South America
# 49       Peru           231.57    2.51      7199.0  South America

# %% [markdown]
# ## ---------------------------------------------------------------------------------------------------------------------------------

# %%
sns.distplot(df["National Income"])

# %% [markdown]
# ### A right skewed distribution because most of data falls on positive side

# %%
#sns.distplot(df[df["Continent"]=="Africa"]["National Income"])
#sns.distplot(dfAfrica["National Income"])
sns.distplot(dfAfrica["National Income"],bins=15)

# %% [markdown]
# ### A symmetric distribution the distribution are roughly equally balanced around the mean. The histogram shows a symmetric distribution.
# ### -----------------------------------------------------------------------------------------------------------------------------

# %%
#sns.distplot(df[df["Continent"]=="Asia"]["National Income"])
sns.distplot(dfAsia["National Income"])

# %% [markdown]
# #### A right skewed distribution because most of data falls on positive side

# %%
#sns.distplot(df[df["Continent"]=="Europe"]["National Income"])
sns.distplot(dfEurope["National Income"],bins=15)

# %% [markdown]
# ### A right skewed distribution because most of data falls on positive side

# %%
sns.distplot(dfnthAmerica["National Income"],bins=15)

# %% [markdown]
# ### A right skewed distribution because most of data falls on positive side

# %%
sns.distplot(dfsthAmerica["National Income"])

# %% [markdown]
# ### A right skewed distribution because most of data falls on positive side

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sns.distplot(df['Growth'],bins=15)

# %% [markdown]
# ##### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %%
sns.distplot(dfAfrica['Growth'],bins=15)

# %% [markdown]
# ### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %%
sns.distplot(dfAsia['Growth'],bins=15)

# %% [markdown]
# #### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %%
sns.distplot(dfEurope['Growth'],bins=15)

# %% [markdown]
# #### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %%
sns.distplot(dfnthAmerica['Growth'],bins=15)

# %% [markdown]
# #### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %%
sns.distplot(dfsthAmerica['Growth'],bins=15)

# %% [markdown]
# #### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %%
sns.distplot(df["Per person"])

# %% [markdown]
# ### A right skewed distribution because most of data falls on positive side

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sns.distplot(dfAfrica['Per person'],bins=15)

# %% [markdown]
# #### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %%
sns.distplot(dfAsia['Per person'],bins=15)

# %% [markdown]
# #### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %%
sns.distplot(dfEurope['Per person'],bins=15)

# %% [markdown]
# ##### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %%
sns.distplot(dfnthAmerica['Per person'])

# %% [markdown]
# ##### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %%
sns.distplot(dfsthAmerica['Per person'])

# %% [markdown]
# #### The histogram shows a symmetric distribution , A symmetric distribution the distribution are roughly equally balanced around the mean

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df.corr()
# Out:
#                  National Income    Growth  Per person
# National Income         1.000000  0.008961    0.159121
# Growth                  0.008961  1.000000   -0.252786
# Per person              0.159121 -0.252786    1.000000

# %%
dfAfrica.corr()
# Out:
#                  National Income    Growth  Per person
# National Income         1.000000 -0.995132    0.181822
# Growth                 -0.995132  1.000000   -0.277850
# Per person              0.181822 -0.277850    1.000000

# %%
dfAsia.corr()
# Out:
#                  National Income    Growth  Per person
# National Income         1.000000  0.172798   -0.042511
# Growth                  0.172798  1.000000   -0.483690
# Per person             -0.042511 -0.483690    1.000000

# %%
dfEurope.corr()
# Out:
#                  National Income    Growth  Per person
# National Income         1.000000 -0.364968    0.050132
# Growth                 -0.364968  1.000000   -0.139235
# Per person              0.050132 -0.139235    1.000000

# %%
dfnthAmerica.corr()
# Out:
#                  National Income    Growth  Per person
# National Income         1.000000 -0.262181    0.720684
# Growth                 -0.262181  1.000000    0.480063
# Per person              0.720684  0.480063    1.000000

# %%
dfsthAmerica.corr()
# Out:
#                  National Income    Growth  Per person
# National Income         1.000000 -0.588445    0.032494
# Growth                 -0.588445  1.000000    0.014210
# Per person              0.032494  0.014210    1.000000

# %%
sns.pairplot(df, hue='Continent', height=3, aspect=1.3)
# Out:
# D:\Anaconda21\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# D:\Anaconda21\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.jointplot(x='National Income',y='Per person',data=df,kind='reg')

# %% [markdown]
# #### very low positive correlation between National income and per person

# %%
sns.jointplot(x='National Income',y='Growth',data=df,kind='reg')

# %% [markdown]
# #### NO correlation between National income and Growth

# %%
sns.jointplot(x='Growth',y='Per person',data=df,kind='reg')

# %% [markdown]
# #### low negative correlation between Growth and per person

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sns.boxplot(x="Continent", y="National Income", data=df)

# %% [markdown]
# ### - The north american continent is greatest income from continents but notional income for countries in this continent was great difference between second Quartile and third Quartile and great difference between fourth Quartile
#
# ### - The europe continent second greatest income from continents and no great difference between national income in this continent countries but national income outliers are marked in this continent
#
# ### - The oceania continent third greatest income from continents and it is only one Country
#
# ### - The Asia continent is the fourth income between continents and no great difference between national income in this continent countries but national income outliers are marked in this continent
#
# ### -The south america continent is the fifth of income between continents and no great difference between national income in this continent countries but national income outliers are marked in this continent
#
# ### - The African continent is the lowest income between continents and no great difference between national income in this continent countries
#
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sns.boxplot(x="Continent", y="Growth", data=df)

# %% [markdown]
# ### - The average rate of growth of Asian continent is the highest rate between continents but it is  great difference between quartiles in this continent
#
# ### -The average rate of growth of Europe continent is the second highest rate between continents but the outliers in this continent are marked
#
# ### -The average rate of growth of oceania continent (Australia) is the third highest rate between continents
#
# ### -The average rate of growth of North america continent is the fourth rate between continents but it is no great difference between quartiles
#
# ### - The average rate of growth of south america continent is the fifth rate between continents but it is no great difference between quartiles in this continent
#
# ### -The average rate of growth of south Africa continent is the lowest rate between continents but it is great difference between quartiles
#
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sns.boxplot(x="Continent", y="Per person", data=df)

# %% [markdown]
# ### - The average rate of per person income of Oceania continent is the highest average rate between continents
#
# ### - The average rate of per person income of north america continent is the second highest average rate between continents but it is great difference between quartiles in this continent
#
# ### -The average rate of per person income of europe continent is the third highest average rate between continents but it is great difference between quartiles in this continent
#
# ### -The average rate of per person income of south america continent is the fourth average rate between continents
#
# ### -The average rate of per person income of asia continent is the fifth average rate between continents but it is great difference between quartiles in this continent
#
# ### -The average rate of per person income of Africa continent is the lowest average rate between continents
#
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#sns.violinplot(x="Continent",y="National Income",data=df)

# %%
sns.violinplot(x="Continent",y="Growth",data=df)

# %% [markdown]
# ### - This violin plot describes density of distribution of Growth rate in every continent
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sns.violinplot(x="Continent", y="Per person", data=df)

# %% [markdown]
# ### - this violin plots shows the density of distribution of Africa and south america between rate of per person income in continent the density distribution are mark but in other continents the density of destribution are not mark
#
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sns.swarmplot(x="Continent",y="National Income",hue="Countries",data=df)

# %% [markdown]
# #### - According to our dataset it is great difference between the united state national income and the other countries in north america
#
# #### - According to our dataset it is great difference between the china national income and the other countries in Asia
#
# #### - According to our dataset it is no great difference between the national income of other countries in each continent

# %%
sns.swarmplot(x="Continent",y="Growth",hue="Countries",data=df)

# %% [markdown]
# #### - The continent that have a large number of countries that have large rate of growth is the Asian Continent but ireland country from europe continent is the greatest rate of growth around all the world countries
#
# #### -The country that has the lowest rate of growth is saudi arabia from Asian continent but i think this is an outlier because this is the only negative value in this column and KSA it is not lowest national income or lowest rate of per person
#
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sns.swarmplot(x="Continent",y="Per person",hue="Countries",data=df)

# %% [markdown]
# ### - The country that has the highest per person rate is Switzerland from europe continent
#
# ### -The country that has the Lowest per person rate is pakistan from Asia continent
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sns.countplot(x='Continent', data=df)

# %% [markdown]
# #### - according to our dataset this graph describes the number of countries in every continent do in descending order : 1- Asia and Europe
#
# #### 2-South america
#
# #### 3-Africa
#
# #### 4-North America
#
# #### 5-Oceania
#
# #### ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # National Income

# %%
sns.barplot(x='Continent', y='National Income', data=df)

# %%
df1 = df.pivot_table(values='National Income', index='Countries', columns='Continent')

# %%
sns.heatmap(df1, linecolor='k')

# %%
sns.barplot(x='Countries', y='National Income', data=dfAfrica)

# %%
sns.barplot(x='National Income', y='Countries', data=dfAsia)

# %%
sns.barplot(x='National Income', y='Countries', data=dfEurope)

# %%
sns.barplot(x='Countries', y='National Income', data=dfOceania)

# %%
sns.barplot(x='Countries', y='National Income', data=dfsthAmerica)

# %%
sns.barplot(x='Countries', y='National Income', data=dfnthAmerica)

# %% [markdown]
# ### --> Africa  <--
#
# #### The greatest income in continent is Nigiria
# #### The lowest income in continent is Egypt
#
# ### --> Asia  <--
# #### The greatest income in continent is China
# #### The lowest income in continent vietnam
#
# ### --> Europe  <--
# #### The greatest income in continent is Germany
# #### The lowest income in continent is Romnia
#
#
# ### --> Nourth America  <--
# #### The greatest income in continent is united states
# #### The lowest income in continent is Mexico
#
#
# ### --> Oceania  <--
# #### The greatest income in continent is Austrlia
#
# ### --> south America  <--
# #### The greatest income in continent is Brazil
# #### The lowest income in continent is Peru
#
#
# ### rank of the greatest 3 national income from countries
#
# #### 1- United State
# #### 2- China
# #### 3- Japan
#
# ### rank of the lowest 3 national income from countries
#
# #### 1- Romania
# #### 2- vietnam
# #### 3- peru
#
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Growth

# %%
sns.barplot(x='Continent', y='Growth', data=df)

# %%
df2 = df.pivot_table(values='Growth', index='Countries', columns='Continent')

# %%
sns.heatmap(df2, linecolor='k')

# %%
sns.barplot(x='Countries', y='Growth', data=dfAfrica)

# %%
sns.barplot(x='Growth', y='Countries', data=dfAsia)

# %%
sns.barplot(x='Growth', y='Countries', data=dfEurope)

# %%
sns.barplot(x='Countries', y='Growth', data=dfOceania)

# %%
sns.barplot(x='Countries', y='Growth', data=dfnthAmerica)

# %%
sns.barplot(x='Countries', y='Growth', data=dfsthAmerica)

# %% [markdown]
# ### --> Africa  <--
#
# #### The greatest rate of Growth in continent is Egypt
# #### The lowest rate of Growth in continent is Nigeria
#
# ### --> Asia  <--
# #### The greatest rate of Growth in continent is Bengaldesh
# #### The lowest rate of Growth in continent is Saudi Arab
#
# ### --> Europe  <--
# #### The greatest rate of Growth in continent is ireland
# #### The lowest rate of Growth in continent is switzerland
#
# ### --> Nourth America  <--
# #### The greatest rate of Growth in continent is canda
# #### The lowest rate of Growth in continent is Mexico
#
# ### --> Oceania  <--
# #### The greatest rate of Growth in continent is Austrlia
#
# ### --> south America  <--
# #### The greatest rate of Growth in continent is Argentina
# #### The lowest rate of Growth in continent is chile
#
#
# ### rank of the greatest 3 national income from countries
#
# #### 1- ierland
# #### 2- Bengaldesh
# #### 3- Romania
#
# ### rank of the lowest 3 national income from countries
#
# #### 1- Nigeria
# #### 2- United Arab Eimrates
# #### 3- Saudi Arab
#
# #### ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Per person

# %%
sns.barplot(x='Continent', y='Per person', data=df)

# %%
df3 = df.pivot_table(values='Per person', index='Countries', columns='Continent')

# %%
sns.heatmap(df3, linecolor='k')

# %%
sns.barplot(x='Countries', y='Per person', data=dfAfrica)

# %%
sns.barplot(x='Per person', y='Countries', data=dfAsia)

# %%
sns.barplot(x='Per person', y='Countries', data=dfEurope)

# %%
sns.barplot(x='Countries', y='Per person', data=dfOceania)

# %%
sns.barplot(x='Countries', y='Per person', data=dfsthAmerica)

# %%
sns.barplot(x='Countries', y='Per person', data=dfnthAmerica)

# %% [markdown]
# ### --> Africa  <--
#
# #### The greatest rate of per person in continent is South Africa
# #### The lowest rate of per person in continent is Nigeria
#
# ### --> Asia  <--
# #### The greatest rate of per person in continent is singapore
# #### The lowest rate of per person in continent is pakistan
#
# ### --> Europe  <--
# #### The greatest rate of per person in continent is switzerland
# #### The lowest rate of per person in continent is Poland
#
# ### --> Nourth America  <--
# #### The greatest rate of per person in continent is United States
# #### The lowest rate of per person in continent is Mexico
#
# ### --> Oceania  <--
# #### The greatest rate of per person in continent is Austrlia
#
# ### --> south America  <--
# #### The greatest rate of per person in continent is Chile
# #### The lowest rate of per person in continent is Colombia
#
#
# ### rank of the greatest 3 national income from countries
#
# #### 1- switzerland
# #### 2- Norway
# #### 3- Ireland
#
# ### rank of the lowest 3 national income from countries
#
# #### 1- Bengaldesh
# #### 2- Poland
# #### 3- pakistan
